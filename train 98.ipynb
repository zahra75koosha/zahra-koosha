# %% [markdown]
# <a href="https://colab.research.google.com/github/zahra75koosha/zahra-koosha/blob/master/train%2098.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 uninstall tensorflow
# !pip3 install tensorflow.gpu==2.0.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/hoda dataset
# %ls
# Out:
# /content/drive/My Drive/hoda dataset
#  hoda_dataset_helper.py   RemainingSamples.cdb  'Train 60000.cdb'
#  __pycache__/            'Test 20000.cdb'

# %%
from hoda_dataset_helper import read_hoda
from hoda_dataset_helper import __read_hoda_dataset
from hoda_dataset_helper import __read_hoda_cdb

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(2)

import tensorflow as tf
from tensorflow.keras import Model 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, MaxPool2D, Dropout, Flatten,GlobalAveragePooling2D
from tensorflow.keras.callbacks import ReduceLROnPlateau

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Load Dataset

# %%
# Reading train dataset 
X_train, Y_train = __read_hoda_dataset(dataset_path='./Train 60000.cdb',
                                images_height=32,
                                images_width=32,
                                one_hot=True, # set one hot= True to encode training_label to one hot vector
                                reshape=True)

# %%
# reading test dataset
X_test, Y_test = __read_hoda_dataset(dataset_path='./Test 20000.cdb',
                              images_height=32,
                              images_width=32,
                              one_hot=True,
                              reshape=False)

# %%
# Reading remain samples dataset 
X_remain, Y_remain = __read_hoda_dataset('./RemainingSamples.cdb',
                                             images_height=32,
                                             images_width=32,
                                             one_hot=True,
                                             reshape=True)

# %%
# reading train image
train_images, train_labels = __read_hoda_cdb('./Train 60000.cdb')

# %%
# reading test image
test_images, test_labels = __read_hoda_cdb('./Test 20000.cdb')

# %%
# plot a data sample

fig = plt.figure(figsize=(15, 3))
plt.imshow(train_images[12])

# %%
#normalization
X_train =X_train / 255.0
X_test = X_test /255.0

# %%
# reshape the train and remain samples to 3 dimension
X_train=X_train.reshape(-1,32,32,1)
X_remain=X_remain.reshape(-1,32,32,1)

# %%
print(f'shape of X_train : {X_train.shape}')
print(f'shape of Y_train : {Y_train.shape}')

print(f'shape of X_test i: {X_test.shape}')
print(f'shape of Y_test  : {Y_test.shape}')

print(f'shape of X_reamin : {X_remain.shape}')
print(f'shape of Y_remain : {Y_remain.shape}')
# Out:
# shape of X_train is : (60000, 32, 32, 1)
# shape of Y_train is : (60000, 10)
# shape of X_test is : (20000, 32, 32, 1)
# shape of Y_test is : (20000, 10)
# shape of X_reamin is : (22352, 32, 32, 1)
# shape of Y_remain is : (22352, 10)

# %%
# split training dataset to validation and train samples
random_seed=2
from sklearn.model_selection import train_test_split
X_train,X_val,Y_train,Y_val= train_test_split(X_train,Y_train,test_size=0.1, random_state=random_seed)

# %%
print(f'shape of X_val is : {X_val.shape}')
print(f'shape of Y_val is : {Y_val.shape}')
# Out:
# shape of X_val is : (6000, 32, 32, 1)
# shape of Y_val is : (6000, 10)

# %% [markdown]
# CNN model

# %%
model= Sequential()

model.add(Conv2D(32,(5,5), activation='relu', padding='same', input_shape=(32,32,1)))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(64,(3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(64,(3,3), activation='relu', padding='same'))

# classifier
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_41 (Conv2D)           (None, 32, 32, 32)        832
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               2097664
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 2,159,050
# Trainable params: 2,159,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
# Set a learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
epochs = 30 
batch_size = 32

# %%
result=model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, 
                 validation_data=(X_val,Y_val), verbose=1,callbacks=[learning_rate_reduction])
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/30
# 53952/54000 [============================>.] - ETA: 0s - loss: 0.3560 - accuracy: 0.8796WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 18s 338us/sample - loss: 0.3558 - accuracy: 0.8797 - val_loss: 0.0675 - val_accuracy: 0.9793
# Epoch 2/30
# 53824/54000 [============================>.] - ETA: 0s - loss: 0.0761 - accuracy: 0.9777WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 17s 317us/sample - loss: 0.0760 - accuracy: 0.9777 - val_loss: 0.0537 - val_accuracy: 0.9842
# Epoch 3/30
# 53824/54000 [============================>.] - ETA: 0s - loss: 0.0554 - accuracy: 0.9838WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] -
ARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 17s 310us/sample - loss: 0.0470 - accuracy: 0.9890 - val_loss: 0.0429 - val_accuracy: 0.9900
# Epoch 20/30
# 53984/54000 [============================>.] - ETA: 0s - loss: 0.0491 - accuracy: 0.9892WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 17s 311us/sample - loss: 0.0490 - accuracy: 0.9892 - val_loss: 0.0343 - val_accuracy: 0.9907
# Epoch 21/30
# 53856/54000 [============================>.] - ETA: 0s - loss: 0.0498 - accuracy: 0.9883WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 17s 315us/sample - loss: 0.0497 - accuracy: 0.9884 - val_loss: 0.0300 - val_accuracy: 0.9920
# Epoch 22/30
# 53984/54000 [============================>.] - ETA: 0s - loss: 0.0493 - accuracy: 0.9890WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 17s 315us/sample - loss: 0.0493 - accuracy: 0.9890 - val_loss: 0.0361 - val_accuracy: 0.9903
# Epoch 23/30
# 53856/54000 [============================>.] - ETA: 0s - loss: 0.0511 - accuracy: 0.9884WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 17s 310us/sample - loss: 0.0510 - accuracy: 0.9884 - val_loss: 0.0357 - val_accuracy: 0.9903
# Epoch 24/30
# 53952/54000 [============================>.] - ETA: 0s - loss: 0.0491 - accuracy: 0.9892WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 17s 309us/sample - loss: 0.0493 - accuracy: 0.9891 - val_loss: 0.0376 - val_accuracy: 0.9928
# Epoch 25/30
# 53920/54000 [============================>.] - ETA: 0s - loss: 0.0521 - accuracy: 0.9886WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 17s 310us/sample - loss: 0.0523 - accuracy: 0.9886 - val_loss: 0.0437 - val_accuracy: 0.9887
# Epoch 26/30
# 53984/54000 [============================>.] - ETA: 0s - loss: 0.0504 - accuracy: 0.9884WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 17s 310us/sample - loss: 0.0504 - accuracy: 0.9884 - val_loss: 0.0364 - val_accuracy: 0.9922
# Epoch 27/30
# 53824/54000 [============================>.] - ETA: 0s - loss: 0.0523 - accuracy: 0.9885WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 17s 309us/sample - loss: 0.0524 - accuracy: 0.9884 - val_loss: 0.0409 - val_accuracy: 0.9880
# Epoch 28/30
# 53824/54000 [============================>.] - ETA: 0s - loss: 0.0522 - accuracy: 0.9881WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 17s 309us/sample - loss: 0.0520 - accuracy: 0.9881 - val_loss: 0.0336 - val_accuracy: 0.9925
# Epoch 29/30
# 53824/54000 [============================>.] - ETA: 0s - loss: 0.0546 - accuracy: 0.9883WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 17s 309us/sample - loss: 0.0544 - accuracy: 0.9883 - val_loss: 0.0350 - val_accuracy: 0.9917
# Epoch 30/30
# 53920/54000 [============================>.] - ETA: 0s - loss: 0.0560 - accuracy: 0.9882WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 54000/54000 [==============================] - 17s 311us/sample - loss: 0.0563 - accuracy: 0.9881 - val_loss: 0.0344 - val_accuracy: 0.9920

# %%
plt.plot(result.history['accuracy'], color='b', label='training accuracy')
plt.plot(result.history['val_accuracy'], color='r', label='validation accuracy')

plt.title('Accuracy Of Model')
plt.ylabel(' Accuracy')
plt.xlabel('  Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
plt.plot(result.history['loss'], color='b', label='training loss')
plt.plot(result.history['val_loss'], color='r', label='validation loss')

plt.title('Loss Of Model')
plt.ylabel(' Loss')
plt.xlabel('  Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
model.evaluate(X_val, Y_val, verbose=1)
# Out:
# 6000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.03435265639148562, 0.992]

# %%
model.evaluate(X_test, Y_test, verbose=1)
print('Test loss:', test_score[0])
print('Test accuracy:', test_score[1])
# Out:
# 20000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test loss: 0.09897835573871344
# Test accuracy: 0.9712

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred,axis = 1)

y_pred = pd.Series(y_pred,name="Label")

# %%
model.save("cnn_model.h5")

# %%
from tensorflow.keras.models import load_model
model_2 = load_model("cnn_model.h5")

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        832
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        25632
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               1048832
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,133,290
# Trainable params: 1,133,290
# Non-trainable params: 0
# _________________________________________________________________
